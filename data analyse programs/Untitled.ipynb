# %%
def mot_lettre_repetee(liste_mot):
    

    


liste_mot["On", "a", "effectuee", "plusieurs", "tests", "elementaire", "ce", "matin"]

print(mot_lettre_repetee(["On", "a", "effectuee", "plusieurs", "tests", "elementaire", "ce", "matin"]))
# Out:
# [90, 120]

# %%
# %%writefile salu.py #creer nouveau fichier avec une fonction
#     def salut():
#         print("bonjour")
#
# !mkdir nom_dossier #creer  nouveau dossier
# Out:
# Writing salu.py

# %%
import numpy as np

#data = np.random.randint(19, size=(7,3))
print("tableau de note de trois matiere phys,maths,svt pour chaque etudiant\n")

print(data)
print(np.sum(data >= 10, axis=1)>=3)
print("nombre d'étudiant qui a la moyenne dans chaque matiere est : \n")
print(np.sum(np.sum(data >= 10, axis=1) >=3))
# Out:
# tableau de note de trois matiere phys,maths,svt pour chaque etudiant
#
# [[17 16 18]
#  [10 17 18]
#  [14 12  8]
#  [15 13  8]
#  [ 9 13  9]
#  [14  2 13]
#  [18  5  1]]
# [ True  True False False False False False]
# nombre d'étudiant qui a la moyenne dans chaque matiere
# 2

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
data = "datasets/SalesAnalysis/Sales_Data/"

# %%
os.listdir(data)
# Out:
# ['Sales_June_2019.csv',
#  'Sales_September_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_December_2019.csv']

# %%
files = [fichier for fichier in os.listdir(data) if fichier.endswith('.csv')]
files
# Out:
# ['Sales_June_2019.csv',
#  'Sales_September_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_December_2019.csv']

# %%
df = pd.DataFrame()

for file in files:
  data_interm = pd.read_csv(data + file)
  df = pd.concat([df, data_interm])

# %%
df.shape
# Out:
# (186850, 6)

# %%
df.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186850 entries, 0 to 25116
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 10.0+ MB

# %%
df.isnull().sum(axis=0)
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
val_manquantes = df[df.isnull().any(axis=1)]
val_manquantes
# Out:
#       Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 339        NaN     NaN              NaN        NaN        NaN              NaN
# 630        NaN     NaN              NaN        NaN        NaN              NaN
# 735        NaN     NaN              NaN        NaN        NaN              NaN
# 1136       NaN     NaN              NaN        NaN        NaN              NaN
# 1349       NaN     NaN              NaN        NaN        NaN              NaN
# ...        ...     ...              ...        ...        ...              ...
# 22945      NaN     NaN              NaN        NaN        NaN              NaN
# 22962      NaN     NaN              NaN        NaN        NaN              NaN
# 23309      NaN     NaN              NaN        NaN        NaN              NaN
# 23996      NaN     NaN              NaN        NaN        NaN              NaN
# 24730      NaN     NaN              NaN        NaN        NaN              NaN
#
# [545 rows x 6 columns]

# %%
val_manquantes.isnull().all()
# Out:
# Order ID            True
# Product             True
# Quantity Ordered    True
# Price Each          True
# Order Date          True
# Purchase Address    True
# dtype: bool

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (186305, 6)

# %%
df.isnull().all()
# Out:
# Order ID            False
# Product             False
# Quantity Ordered    False
# Price Each          False
# Order Date          False
# Purchase Address    False
# dtype: bool

# %%
df['Order ID']
# Out:
# 0        209921
# 1        209922
# 2        209923
# 3        209924
# 4        209925
#           ...
# 25112    319666
# 25113    319667
# 25114    319668
# 25115    319669
# 25116    319670
# Name: Order ID, Length: 186305, dtype: object

# %%
df[df['Order Date'] == 'Order Date']
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 158    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 990    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1679   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1684   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3126   Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...         ...      ...               ...         ...         ...
# 23198  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 23337  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 23748  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 24192  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 24222  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#        Purchase Address
# 158    Purchase Address
# 990    Purchase Address
# 1679   Purchase Address
# 1684   Purchase Address
# 3126   Purchase Address
# ...                 ...
# 23198  Purchase Address
# 23337  Purchase Address
# 23748  Purchase Address
# 24192  Purchase Address
# 24222  Purchase Address
#
# [355 rows x 6 columns]

# %%
df_clean = df.drop(df.loc[df['Order Date'] == 'Order Date', :].index)

# %%
df_clean.loc[~df_clean['Order ID'].str.isdigit(), :]
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address]
# Index: []

# %%
df_clean.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   209921        USB-C Charging Cable                1      11.95
# 1   209922          Macbook Pro Laptop                1     1700.0
# 2   209923             ThinkPad Laptop                1     999.99
# 3   209924            27in FHD Monitor                1     149.99
# 4   209925  Bose SoundSport Headphones                1      99.99
#
#        Order Date                       Purchase Address
# 0  06/23/19 19:34      950 Walnut St, Portland, ME 04101
# 1  06/30/19 10:05     80 4th St, San Francisco, CA 94016
# 2  06/24/19 20:18  402 Jackson St, Los Angeles, CA 90001
# 3  06/05/19 10:21         560 10th St, Seattle, WA 98101
# 4  06/25/19 18:58    545 2nd St, San Francisco, CA 94016

# %%
df_clean['Quantity Ordered'] = df_clean['Quantity Ordered'].astype(int)

# %%
df_clean['Price Each'] = pd.to_numeric(df_clean['Price Each'])

# %%
df_clean['Order Date'] = pd.to_datetime(df_clean['Order Date'])

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182735 entries, 0 to 25116
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          182735 non-null  object
#  1   Product           182735 non-null  object
#  2   Quantity Ordered  182735 non-null  int64
#  3   Price Each        182735 non-null  float64
#  4   Order Date        182735 non-null  datetime64[ns]
#  5   Purchase Address  182735 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 9.8+ MB

# %%
df_clean = df_clean.set_index('Order Date')

# %%
df_clean.head()
# Out:
#                     Order ID                     Product  Quantity Ordered  \
# Order Date
# 2019-06-23 19:34:00   209921        USB-C Charging Cable                 1
# 2019-06-30 10:05:00   209922          Macbook Pro Laptop                 1
# 2019-06-24 20:18:00   209923             ThinkPad Laptop                 1
# 2019-06-05 10:21:00   209924            27in FHD Monitor                 1
# 2019-06-25 18:58:00   209925  Bose SoundSport Headphones                 1
#
#                      Price Each                       Purchase Address
# Order Date
# 2019-06-23 19:34:00       11.95      950 Walnut St, Portland, ME 04101
# 2019-06-30 10:05:00     1700.00     80 4th St, San Francisco, CA 94016
# 2019-06-24 20:18:00      999.99  402 Jackson St, Los Angeles, CA 90001
# 2019-06-05 10:21:00      149.99         560 10th St, Seattle, WA 98101
# 2019-06-25 18:58:00       99.99    545 2nd St, San Francisco, CA 94016

# %%
df_clean.sort_index(inplace=True)

# %%
df_clean.head()
# Out:
#                     Order ID                   Product  Quantity Ordered  \
# Order Date
# 2019-01-01 03:07:00   147268          Wired Headphones                 1
# 2019-01-01 03:40:00   148041      USB-C Charging Cable                 1
# 2019-01-01 04:56:00   149343  Apple Airpods Headphones                 1
# 2019-01-01 05:53:00   149964    AAA Batteries (4-pack)                 1
# 2019-01-01 06:03:00   149350      USB-C Charging Cable                 2
#
#                      Price Each                        Purchase Address
# Order Date
# 2019-01-01 03:07:00       11.99      9 Lake St, New York City, NY 10001
# 2019-01-01 03:40:00       11.95  760 Church St, San Francisco, CA 94016
# 2019-01-01 04:56:00      150.00     735 5th St, New York City, NY 10001
# 2019-01-01 05:53:00        2.99         75 Jackson St, Dallas, TX 75001
# 2019-01-01 06:03:00       11.95           943 2nd St, Atlanta, GA 30301

# %%
df_clean['Month'] = df_clean.index.month_name()

# %%
df_clean.head()
# Out:
#                     Order ID                   Product  Quantity Ordered  \
# Order Date
# 2019-01-01 03:07:00   147268          Wired Headphones                 1
# 2019-01-01 03:40:00   148041      USB-C Charging Cable                 1
# 2019-01-01 04:56:00   149343  Apple Airpods Headphones                 1
# 2019-01-01 05:53:00   149964    AAA Batteries (4-pack)                 1
# 2019-01-01 06:03:00   149350      USB-C Charging Cable                 2
#
#                      Price Each                        Purchase Address  \
# Order Date
# 2019-01-01 03:07:00       11.99      9 Lake St, New York City, NY 10001
# 2019-01-01 03:40:00       11.95  760 Church St, San Francisco, CA 94016
# 2019-01-01 04:56:00      150.00     735 5th St, New York City, NY 10001
# 2019-01-01 05:53:00        2.99         75 Jackson St, Dallas, TX 75001
# 2019-01-01 06:03:00       11.95           943 2nd St, Atlanta, GA 30301
#
#                        Month
# Order Date
# 2019-01-01 03:07:00  January
# 2019-01-01 03:40:00  January
# 2019-01-01 04:56:00  January
# 2019-01-01 05:53:00  January
# 2019-01-01 06:03:00  January

# %%
df_clean['chiffre_daffaire'] = df_clean['Quantity Ordered'] * df_clean['Price Each']

# %%
df_clean.head()
# Out:
#                     Order ID                   Product  Quantity Ordered  \
# Order Date
# 2019-01-01 03:07:00   147268          Wired Headphones                 1
# 2019-01-01 03:40:00   148041      USB-C Charging Cable                 1
# 2019-01-01 04:56:00   149343  Apple Airpods Headphones                 1
# 2019-01-01 05:53:00   149964    AAA Batteries (4-pack)                 1
# 2019-01-01 06:03:00   149350      USB-C Charging Cable                 2
#
#                      Price Each                        Purchase Address  \
# Order Date
# 2019-01-01 03:07:00       11.99      9 Lake St, New York City, NY 10001
# 2019-01-01 03:40:00       11.95  760 Church St, San Francisco, CA 94016
# 2019-01-01 04:56:00      150.00     735 5th St, New York City, NY 10001
# 2019-01-01 05:53:00        2.99         75 Jackson St, Dallas, TX 75001
# 2019-01-01 06:03:00       11.95           943 2nd St, Atlanta, GA 30301
#
#                        Month  chiffre_daffaire
# Order Date
# 2019-01-01 03:07:00  January             11.99
# 2019-01-01 03:40:00  January             11.95
# 2019-01-01 04:56:00  January            150.00
# 2019-01-01 05:53:00  January              2.99
# 2019-01-01 06:03:00  January             23.90

# %%
df_clean.groupby('Month')['chiffre_daffaire'].sum().sort_values(ascending=False)
# Out:
# Month
# December     4557905.42
# October      3679254.16
# April        3336376.42
# November     3149785.09
# May          3101881.04
# March        2755969.40
# July         2587444.91
# June         2524464.99
# August       2191698.31
# February     2158127.48
# September    2050361.26
# January      1786511.29
# Name: chiffre_daffaire, dtype: float64

# %%
sns.countplot(x = "Month", data= df_clean)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='count'>

# %%
order = ["January", "February", "March", "April", "May", "June", "July", "August",
                  "September", "October", "November", "December"]

# %%
df_clean.groupby('Month')["chiffre_daffaire"].sum().loc[order].plot.bar(figsize=(10, 8))
plt.title("Chiffre d'affaire global par mois")
# Out:
# Text(0.5, 1.0, "Chiffre d'affaire global par mois")

# %%
df_clean.groupby('Month').sum()["chiffre_daffaire"].sort_values(ascending=False).December
# Out:
# 4557905.42

# %%
def get_ville(addresse):
    return addresse.split(',')[1].strip()

# %%
df_clean['ville']  = df_clean['Purchase Address'].apply(get_ville)

# %%
df_clean.head()
# Out:
#                     Order ID                   Product  Quantity Ordered  \
# Order Date
# 2019-01-01 03:07:00   147268          Wired Headphones                 1
# 2019-01-01 03:40:00   148041      USB-C Charging Cable                 1
# 2019-01-01 04:56:00   149343  Apple Airpods Headphones                 1
# 2019-01-01 05:53:00   149964    AAA Batteries (4-pack)                 1
# 2019-01-01 06:03:00   149350      USB-C Charging Cable                 2
#
#                      Price Each                        Purchase Address  \
# Order Date
# 2019-01-01 03:07:00       11.99      9 Lake St, New York City, NY 10001
# 2019-01-01 03:40:00       11.95  760 Church St, San Francisco, CA 94016
# 2019-01-01 04:56:00      150.00     735 5th St, New York City, NY 10001
# 2019-01-01 05:53:00        2.99         75 Jackson St, Dallas, TX 75001
# 2019-01-01 06:03:00       11.95           943 2nd St, Atlanta, GA 30301
#
#                        Month  chiffre_daffaire          ville
# Order Date
# 2019-01-01 03:07:00  January             11.99  New York City
# 2019-01-01 03:40:00  January             11.95  San Francisco
# 2019-01-01 04:56:00  January            150.00  New York City
# 2019-01-01 05:53:00  January              2.99         Dallas
# 2019-01-01 06:03:00  January             23.90        Atlanta

# %%
df_clean.groupby('ville')['chiffre_daffaire'].sum().sort_values(ascending=False)
# Out:
# ville
# San Francisco    8124120.94
# Los Angeles      5354039.93
# New York City    4581658.91
# Boston           3604080.86
# Atlanta          2741642.05
# Dallas           2717793.72
# Seattle          2693048.60
# Portland         2276649.24
# Austin           1786745.52
# Name: chiffre_daffaire, dtype: float64

# %%
df_clean.groupby('ville')["chiffre_daffaire"].sum().sort_values(ascending=False).plot.barh(figsize=(10, 8))
plt.title("Chiffre d'affaire global par ville")
# Out:
# Text(0.5, 1.0, "Chiffre d'affaire global par ville")

# %%
df_clean['heure'] = df_clean.index.hour
df_clean['time'] = df_clean.index.time

# %%
df_clean.head()
# Out:
#                     Order ID                   Product  Quantity Ordered  \
# Order Date
# 2019-01-01 03:07:00   147268          Wired Headphones                 1
# 2019-01-01 03:40:00   148041      USB-C Charging Cable                 1
# 2019-01-01 04:56:00   149343  Apple Airpods Headphones                 1
# 2019-01-01 05:53:00   149964    AAA Batteries (4-pack)                 1
# 2019-01-01 06:03:00   149350      USB-C Charging Cable                 2
#
#                      Price Each                        Purchase Address  \
# Order Date
# 2019-01-01 03:07:00       11.99      9 Lake St, New York City, NY 10001
# 2019-01-01 03:40:00       11.95  760 Church St, San Francisco, CA 94016
# 2019-01-01 04:56:00      150.00     735 5th St, New York City, NY 10001
# 2019-01-01 05:53:00        2.99         75 Jackson St, Dallas, TX 75001
# 2019-01-01 06:03:00       11.95           943 2nd St, Atlanta, GA 30301
#
#                        Month  chiffre_daffaire          ville  heure      time
# Order Date
# 2019-01-01 03:07:00  January             11.99  New York City      3  03:07:00
# 2019-01-01 03:40:00  January             11.95  San Francisco      3  03:40:00
# 2019-01-01 04:56:00  January            150.00  New York City      4  04:56:00
# 2019-01-01 05:53:00  January              2.99         Dallas      5  05:53:00
# 2019-01-01 06:03:00  January             23.90        Atlanta      6  06:03:00

# %%
df_clean.groupby('heure')['chiffre_daffaire'].sum().sort_values(ascending=False)
# Out:
# heure
# 19    2370005.59
# 12    2269676.91
# 11    2267169.73
# 20    2242856.37
# 18    2176209.65
# 13    2118394.83
# 17    2086082.23
# 14    2045085.42
# 21    2013288.02
# 10    1907179.29
# 15    1900151.56
# 16    1864530.92
# 9     1612498.90
# 22    1578173.21
# 8     1181363.76
# 23    1161803.96
# 7      734595.75
# 0      698694.76
# 1      447663.86
# 6      441523.14
# 2      234191.08
# 5      224313.72
# 4      161350.57
# 3      142976.54
# Name: chiffre_daffaire, dtype: float64

# %%
ca_par_heure = pd.DataFrame(df_clean.groupby('heure')['chiffre_daffaire'].sum())

# %%
ca_par_heure
# Out:
#        chiffre_daffaire
# heure
# 0             698694.76
# 1             447663.86
# 2             234191.08
# 3             142976.54
# 4             161350.57
# 5             224313.72
# 6             441523.14
# 7             734595.75
# 8            1181363.76
# 9            1612498.90
# 10           1907179.29
# 11           2267169.73
# 12           2269676.91
# 13           2118394.83
# 14           2045085.42
# 15           1900151.56
# 16           1864530.92
# 17           2086082.23
# 18           2176209.65
# 19           2370005.59
# 20           2242856.37
# 21           2013288.02
# 22           1578173.21
# 23           1161803.96

# %%
sns.lineplot(data=ca_par_heure['chiffre_daffaire'])
plt.xticks(ticks=range(0, 24))
plt.grid()
plt.show()

# %%
df_m = df_clean[df_clean['Order ID'].duplicated(keep=False)].copy()
df_m
# Out:
#                     Order ID                     Product  Quantity Ordered  \
# Order Date
# 2019-01-01 07:29:00   144804            Wired Headphones                 1
# 2019-01-01 07:29:00   144804                      iPhone                 1
# 2019-01-01 11:25:00   148074        USB-C Charging Cable                 1
# 2019-01-01 11:25:00   148074                Google Phone                 1
# 2019-01-01 12:02:00   148450                      iPhone                 1
# ...                      ...                         ...               ...
# 2020-01-01 00:10:00   311386    Apple Airpods Headphones                 1
# 2020-01-01 00:22:00   297817                      iPhone                 1
# 2020-01-01 00:22:00   297817    Lightning Charging Cable                 2
# 2020-01-01 05:13:00   300519  Bose SoundSport Headphones                 1
# 2020-01-01 05:13:00   300519    Lightning Charging Cable                 1
#
#                      Price Each                        Purchase Address  \
# Order Date
# 2019-01-01 07:29:00       11.99    628 Lake St, New York City, NY 10001
# 2019-01-01 07:29:00      700.00    628 Lake St, New York City, NY 10001
# 2019-01-01 11:25:00       11.95         6 Johnson St, Atlanta, GA 30301
# 2019-01-01 11:25:00      600.00         6 Johnson St, Atlanta, GA 30301
# 2019-01-01 12:02:00      700.00       761 Lakeview St, Dallas, TX 75001
# ...                         ...                                     ...
# 2020-01-01 00:10:00      150.00    730 Pine St, San Francisco, CA 94016
# 2020-01-01 00:22:00      700.00    519 13th St, New York City, NY 10001
# 2020-01-01 00:22:00       14.95    519 13th St, New York City, NY 10001
# 2020-01-01 05:13:00       99.99  657 Spruce St, New York City, NY 10001
# 2020-01-01 05:13:00       14.95  657 Spruce St, New York City, NY 10001
#
#                        Month  chiffre_daffaire          ville  heure      time
# Order Date
# 2019-01-01 07:29:00  January             11.99  New York City      7  07:29:00
# 2019-01-01 07:29:00  January            700.00  New York City      7  07:29:00
# 2019-01-01 11:25:00  January             11.95        Atlanta     11  11:25:00
# 2019-01-01 11:25:00  January            600.00        Atlanta     11  11:25:00
# 2019-01-01 12:02:00  January            700.00         Dallas     12  12:02:00
# ...                      ...               ...            ...    ...       ...
# 2020-01-01 00:10:00  January            150.00  San Francisco      0  00:10:00
# 2020-01-01 00:22:00  January            700.00  New York City      0  00:22:00
# 2020-01-01 00:22:00  January             29.90  New York City      0  00:22:00
# 2020-01-01 05:13:00  January             99.99  New York City      5  05:13:00
# 2020-01-01 05:13:00  January             14.95  New York City      5  05:13:00
#
# [14214 rows x 10 columns]

# %%
def concat_produit_par_order_id(p: list):
  return ";".join(p)

# %%
df_m.groupby('Order ID')['Product'].apply(concat_produit_par_order_id)
# Out:
# Order ID
# 141275              USB-C Charging Cable;Wired Headphones
# 141290     Apple Airpods Headphones;AA Batteries (4-pack)
# 141365                   Wired Headphones;Vareebadd Phone
# 141384                  Google Phone;USB-C Charging Cable
# 141450            Google Phone;Bose SoundSport Headphones
#                                ...
# 319536                Wired Headphones;Macbook Pro Laptop
# 319556                      Google Phone;Wired Headphones
# 319584                            iPhone;Wired Headphones
# 319596                    iPhone;Lightning Charging Cable
# 319631    34in Ultrawide Monitor;Lightning Charging Cable
# Name: Product, Length: 6928, dtype: object

# %%
ensemble = df_m.groupby('Order ID')['Product'].apply(concat_produit_par_order_id)

# %%
from itertools import combinations
from collections import Counter

count = Counter()

# %%
ensemble.to_list()
# Out:
# ['USB-C Charging Cable;Wired Headphones',
#  'Apple Airpods Headphones;AA Batteries (4-pack)',
#  'Wired Headphones;Vareebadd Phone',
#  'Google Phone;USB-C Charging Cable',
#  'Google Phone;Bose SoundSport Headphones',
#  'iPhone;Apple Airpods Headphones',
#  'Apple Airpods Headphones;Google Phone',
#  'Apple Airpods Headphones;iPhone;Wired Headphones',
#  'USB-C Charging Cable;Apple Airpods Headphones',
#  'Lightning Charging Cable;Wired Headphones',
#  'Lightning Charging Cable;iPhone',
#  'Bose SoundSport Headphones;27in FHD Monitor',
#  'USB-C Charging Cable;Google Phone',
#  'Wired Headphones;iPhone',
#  'USB-C Charging Cable;Google Phone',
#  'AAA Batteries (4-pack);AA Batteries (4-pack)',
#  'Wired Headphones;USB-C Charging Cable;Vareebadd Phone',
#  'Google Phone;USB-C Charging Cable',
#  'Vareebadd Phone;Wired Headphones',
#  'Lightning Charging Cable;34in Ultrawide Monitor',
#  'USB-C Charging Cable;Wired Headphones',
#  'Bose SoundSport Headphones;Lightning Charging Cable',
#  'Wired Headphones;Google Phone',
#  'iPhone;Wired Headphones',
#  'Lightning Charging Cable;Apple Airpods Headphones',
#  'Google Phone;iPhone',
#  'iPhone;Wired Headphones',
#  'iPhone;Lightning Charging Cable',
#  '20in Monitor;Wired Headphones',
#  'Apple Airpods Headphones;iPhone',
#  'Google Phone;USB-C Charging Cable',
#  'Google Phone;Wired Headphones',
#  'AA Batteries (4-pack);AA Batteries (4-pack)',
#  'Lightning Charging Cable;iPhone',
#  '20in Monitor;Bose SoundSport Headphones',
#  'Wired Headphones;Bose SoundSport Headphones;Google Phone',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'Apple Airpods Headphones;USB-C Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'Google Phone;USB-C Charging Cable',
#  'Wired Headphones;iPhone',
#  'Google Phone;USB-C Charging Cable;Wired Headphones',
#  'Wired Headphones;iPhone',
#  'Google Phone;Wired Headphones',
#  'Bose SoundSport Headphones;Google Phone',
#  'iPhone;Google Phone',
#  'Google Phone;USB-C Charging Cable',
#  'Lightning Charging Cable;iPhone',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'Google Phone;Wired Headphones',
#  'Vareebadd Phone;Bose SoundSport Headphones',
#  'USB-C Charging Cable;Google Phone',
#  'Lightning Charging Cable;iPhone',
#  'AA Batteries (4-pack);AAA Batteries (4-pack)',
#  'Lightning Charging Cable;iPhone',
#  'Apple Airpods Headphones;iPhone',
#  'Google Phone;USB-C Charging Cable',
#  'AAA Batteries (4-pack);27in 4K Gaming Monitor',
#  'AA Batteries (4-pack);USB-C Charging Cable',
#  'USB-C Charging Cable;Lightning Charging Cable',
#  'USB-C Charging Cable;Wired Headphones',
#  'AA Batteries (4-pack);Macbook Pro Laptop',
#  'Google Phone;USB-C Charging Cable',
#  'Bose SoundSport Headphones;Macbook Pro Laptop',
#  'Lightning Charging Cable;iPhone',
#  'Wired Headphones;Google Phone',
#  'iPhone;Wired Headphones',
#  'Wired Headphones;iPhone',
#  'Wired Headphones;34in Ultrawide Monitor',
#  'iPhone;Lightning Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'iPhone;Wired Headphones',
#  'Google Phone;Bose SoundSport Headphones;Wired Headphones',
#  'Lightning Charging Cable;iPhone;Apple Airpods Headphones',
#  'Lightning Charging Cable;iPhone',
#  'Wired Headphones;AA Batteries (4-pack)',
#  '20in Monitor;USB-C Charging Cable',
#  'Lightning Charging Cable;Apple Airpods Headphones',
#  'Wired Headphones;iPhone',
#  'Bose SoundSport Headphones;Apple Airpods Headphones',
#  'Google Phone;USB-C Charging Cable',
#  'Lightning Charging Cable;Apple Airpods Headphones',
#  'Wired Headphones;Lightning Charging Cable',
#  'ThinkPad Laptop;Wired Headphones',
#  'LG Dryer;Flatscreen TV',
#  'USB-C Charging Cable;Google Phone',
#  'Apple Airpods Headphones;AAA Batteries (4-pack)',
#  'iPhone;Lightning Charging Cable;Wired Headphones',
#  'Google Phone;USB-C Charging Cable',
#  'Google Phone;Wired Headphones',
#  'USB-C Charging Cable;Google Phone',
#  'Google Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'AAA Batteries (4-pack);27in 4K Gaming Monitor',
#  'AA Batteries (4-pack);Bose SoundSport Headphones',
#  '34in Ultrawide Monitor;Lightning Charging Cable',
#  'USB-C Charging Cable;Apple Airpods Headphones',
#  'ThinkPad Laptop;Apple Airpods Headphones',
#  'USB-C Charging Cable;Google Phone',
#  'Google Phone;Wired Headphones',
#  'Flatscreen TV;AAA Batteries (4-pack)',
#  'iPhone;Wired Headphones',
#  'Wired Headphones;Vareebadd Phone',
#  'USB-C Charging Cable;AAA Batteries (4-pack)',
#  'Lightning Charging Cable;iPhone',
#  'USB-C Charging Cable;27in FHD Monitor',
#  '27in 4K Gaming Monitor;AA Batteries (4-pack)',
#  'Wired Headphones;iPhone',
#  'Google Phone;USB-C Charging Cable;Wired Headphones',
#  '20in Monitor;USB-C Charging Cable',
#  'Google Phone;USB-C Charging Cable',
#  'iPhone;Lightning Charging Cable',
#  'iPhone;Lightning Charging Cable',
#  'AA Batteries (4-pack);Wired Headphones',
#  'Lightning Charging Cable;iPhone',
#  'iPhone;Wired Headphones',
#  'iPhone;27in 4K Gaming Monitor',
#  'Wired Headphones;Bose SoundSport Headphones',
#  'AAA Batteries (4-pack);Lightning Charging Cable',
#  'iPhone;Wired Headphones',
#  'iPhone;Wired Headphones',
#  'USB-C Charging Cable;Google Phone',
#  'USB-C Charging Cable;Google Phone',
#  'Wired Headphones;iPhone',
#  'Google Phone;Bose SoundSport Headphones',
#  'Lightning Charging Cable;USB-C Charging Cable',
#  '27in FHD Monitor;Lightning Charging Cable',
#  'Apple Airpods Headphones;iPhone',
#  'USB-C Charging Cable;Flatscreen TV',
#  'LG Washing Machine;Bose SoundSport Headphones',
#  'iPhone;Lightning Charging Cable',
#  'Wired Headphones;iPhone',
#  'USB-C Charging Cable;Google Phone',
#  'Google Phone;Wired Headphones',
#  'Lightning Charging Cable;iPhone',
#  'Wired Headphones;Google Phone',
#  'Lightning Charging Cable;Macbook Pro Laptop',
#  'USB-C Charging Cable;Lightning Charging Cable',
#  'Google Phone;USB-C Charging Cable',
#  'iPhone;Apple Airpods Headphones',
#  'USB-C Charging Cable;Google Phone',
#  'Bose SoundSport Headphones;Wired Headphones',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'AAA Batteries (4-pack);AA Batteries (4-pack)',
#  'Lightning Charging Cable;iPhone',
#  'USB-C Charging Cable;Google Phone',
#  'iPhone;Lightning Charging Cable',
#  'Lightning Charging Cable;iPhone',
#  'Wired Headphones;Google Phone',
#  'USB-C Charging Cable;Google Phone',
#  'iPhone;USB-C Charging Cable',
#  'Google Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'Wired Headphones;iPhone',
#  'Lightning Charging Cable;iPhone',
#  'Wired Headphones;Bose SoundSport Headphones',
#  'Google Phone;USB-C Charging Cable',
#  'Wired Headphones;iPhone',
#  'USB-C Charging Cable;Google Phone',
#  'Wired Headphones;iPhone',
#  'Wired Headphones;Lightning Charging Cable;iPhone',
#  'USB-C Charging Cable;Google Phone',
#  'Google Phone;USB-C Charging Cable',
#  'Apple Airpods Headphones;USB-C Charging Cable',
#  'AA Batteries (4-pack);Lightning Charging Cable',
#  'Wired Headphones;20in Monitor',
#  'AA Batteries (4-pack);27in 4K Gaming Monitor',
#  'iPhone;Wired Headphones',
#  'Bose SoundSport Headphones;Vareebadd Phone',
#  'USB-C Charging Cable;Google Phone;Wired Headphones',
#  '20in Monitor;Wired Headphones',
#  'iPhone;Lightning Charging Cable',
#  'iPhone;Wired Headphones;Lightning Charging Cable',
#  'AA Batteries (4-pack);USB-C Charging Cable',
#  'AA Batteries (4-pack);LG Dryer',
#  'USB-C Charging Cable;Bose SoundSport Headphones',
#  'Google Phone;USB-C Charging Cable',
#  'Apple Airpods Headphones;AAA Batteries (4-pack)',
#  'Lightning Charging Cable;Lightning Charging Cable',
#  'Google Phone;Wired Headphones',
#  'Vareebadd Phone;AAA Batteries (4-pack)',
#  'Lightning Charging Cable;iPhone',
#  'Google Phone;Wired Headphones',
#  'Apple Airpods Headphones;Flatscreen TV',
#  'Lightning Charging Cable;iPhone',
#  'AAA Batteries (4-pack);Wired Headphones',
#  'AAA Batteries (4-pack);Bose SoundSport Headphones',
#  'AAA Batteries (4-pack);Flatscreen TV',
#  'Google Phone;USB-C Charging Cable',
#  '20in Monitor;Bose SoundSport Headphones',
#  'AAA Batteries (4-pack);Lightning Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'Lightning Charging Cable;iPhone',
#  'USB-C Charging Cable;Apple Airpods Headphones',
#  'Google Phone;USB-C Charging Cable;Bose SoundSport Headphones',
#  'AAA Batteries (4-pack);Wired Headphones',
#  'iPhone;Lightning Charging Cable',
#  'Wired Headphones;ThinkPad Laptop',
#  'Wired Headphones;Google Phone',
#  'Lightning Charging Cable;Flatscreen TV',
#  'Wired Headphones;AA Batteries (4-pack)',
#  'USB-C Charging Cable;iPhone',
#  'Lightning Charging Cable;iPhone',
#  'Wired Headphones;AAA Batteries (4-pack)',
#  'USB-C Charging Cable;Bose SoundSport Headphones',
#  'USB-C Charging Cable;Google Phone',
#  'Wired Headphones;Vareebadd Phone;USB-C Charging Cable',
#  '27in 4K Gaming Monitor;AA Batteries (4-pack)',
#  'Lightning Charging Cable;Google Phone',
#  'Wired Headphones;iPhone',
#  'Wired Headphones;USB-C Charging Cable',
#  'Flatscreen TV;AA Batteries (4-pack)',
#  'Lightning Charging Cable;AA Batteries (4-pack)',
#  'Apple Airpods Headphones;iPhone',
#  'iPhone;Lightning Charging Cable',
#  'Lightning Charging Cable;iPhone',
#  'iPhone;Lightning Charging Cable',
#  'AAA Batteries (4-pack);AA Batteries (4-pack)',
#  'USB-C Charging Cable;Google Phone',
#  'Flatscreen TV;34in Ultrawide Monitor',
#  'USB-C Charging Cable;Wired Headphones',
#  'Bose SoundSport Headphones;27in FHD Monitor',
#  '27in FHD Monitor;AAA Batteries (4-pack)',
#  'LG Dryer;AA Batteries (4-pack)',
#  'Wired Headphones;iPhone',
#  'USB-C Charging Cable;Wired Headphones',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'Bose SoundSport Headphones;Lightning Charging Cable',
#  'Flatscreen TV;Apple Airpods Headphones',
#  'Google Phone;USB-C Charging Cable',
#  'Apple Airpods Headphones;Lightning Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'Google Phone;Google Phone',
#  'Google Phone;Wired Headphones',
#  'Wired Headphones;Google Phone',
#  'Apple Airpods Headphones;Lightning Charging Cable',
#  'iPhone;Apple Airpods Headphones',
#  'iPhone;Apple Airpods Headphones',
#  'iPhone;Apple Airpods Headphones',
#  'iPhone;Apple Airpods Headphones',
#  'iPhone;Wired Headphones',
#  '27in FHD Monitor;27in 4K Gaming Monitor',
#  'Google Phone;Wired Headphones',
#  'Wired Headphones;Bose SoundSport Headphones',
#  'USB-C Charging Cable;Google Phone',
#  'AA Batteries (4-pack);34in Ultrawide Monitor',
#  'Flatscreen TV;Wired Headphones',
#  'AAA Batteries (4-pack);27in FHD Monitor',
#  'Lightning Charging Cable;Wired Headphones',
#  'Apple Airpods Headphones;iPhone',
#  'iPhone;Wired Headphones',
#  'iPhone;Lightning Charging Cable',
#  'Google Phone;Wired Headphones',
#  'Google Phone;Wired Headphones',
#  'Apple Airpods Headphones;Wired Headphones',
#  'AA Batteries (4-pack);Lightning Charging Cable',
#  'Lightning Charging Cable;Google Phone',
#  'Google Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;20in Monitor',
#  'USB-C Charging Cable;Google Phone',
#  'USB-C Charging Cable;Google Phone',
#  '27in 4K Gaming Monitor;USB-C Charging Cable',
#  'USB-C Charging Cable;AAA Batteries (4-pack)',
#  'iPhone;Wired Headphones',
#  'AA Batteries (4-pack);Wired Headphones',
#  'Wired Headphones;Google Phone',
#  'iPhone;Lightning Charging Cable',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'Wired Headphones;Google Phone',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'Lightning Charging Cable;iPhone',
#  'Google Phone;USB-C Charging Cable;Wired Headphones',
#  'Flatscreen TV;Apple Airpods Headphones',
#  'Google Phone;Wired Headphones',
#  'Google Phone;USB-C Charging Cable',
#  'iPhone;Apple Airpods Headphones;Wired Headphones',
#  'AAA Batteries (4-pack);34in Ultrawide Monitor',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'Wired Headphones;Wired Headphones',
#  'Vareebadd Phone;USB-C Charging Cable;Wired Headphones',
#  'Google Phone;USB-C Charging Cable',
#  'Bose SoundSport Headphones;USB-C Charging Cable;Google Phone',
#  'Google Phone;USB-C Charging Cable;AA Batteries (4-pack)',
#  'Lightning Charging Cable;iPhone',
#  'Lightning Charging Cable;iPhone',
#  'Apple Airpods Headphones;Macbook Pro Laptop',
#  'USB-C Charging Cable;Google Phone',
#  'Lightning Charging Cable;iPhone',
#  'Lightning Charging Cable;iPhone',
#  'Lightning Charging Cable;iPhone',
#  'USB-C Charging Cable;34in Ultrawide Monitor',
#  'USB-C Charging Cable;Google Phone',
#  'AA Batteries (4-pack);Lightning Charging Cable',
#  'Google Phone;USB-C Charging Cable',
#  'Vareebadd Phone;USB-C Charging Cable',
#  '20in Monitor;Lightning Charging Cable',
#  'iPhone;Lightning Charging Cable',
#  'iPhone;Apple Airpods Headphones',
#  'iPhone;Lightning Charging Cable',
#  'iPhone;Lightning Charging Cable',
#  'iPhone;Lightning Charging Cable',
#  'Bose SoundSport Headphones;AA Batteries (4-pack)',
#  'USB-C Charging Cable;AA Batteries (4-pack)',
#  'AAA Batteries (4-pack);Apple Airpods Headphones',
#  'USB-C Charging Cable;AAA Batteries (4-pack)',
#  'ThinkPad Laptop;USB-C Charging Cable',
#  'iPhone;Lightning Charging Cable',
#  'Wired Headphones;iPhone',
#  'AAA Batteries (4-pack);Lightning Charging Cable',
#  'Wired Headphones;USB-C Charging Cable',
#  'Lightning Charging Cable;iPhone',
#  'Macbook Pro Laptop;Bose SoundSport Headphones',
#  'Vareebadd Phone;Wired Headphones;USB-C Charging Cable',
#  'iPhone;Wired Headphones',
#  'AAA Batteries (4-pack);Wired Headphones',
#  'iPhone;Lightning Charging Cable',
#  'Google Phone;USB-C Charging Cable',
#  'Bose SoundSport Headphones;27in 4K Gaming Monitor',
#  'USB-C Charging Cable;USB-C Charging Cable',
#  'AA Batteries (4-pack);Flatscreen TV',
#  'Lightning Charging Cable;27in 4K Gaming Monitor',
#  'Apple Airpods Headphones;AA Batteries (4-pack)',
#  'Bose SoundSport Headphones;Google Phone',
#  'Vareebadd Phone;Wired Headphones;USB-C Charging Cable',
#  'Lightning Charging Cable;Lightning Charging Cable',
#  'Google Phone;USB-C Charging Cable',
#  'Apple Airpods Headphones;Apple Airpods Headphones',
#  '27in FHD Monitor;Apple Airpods Headphones',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'Lightning Charging Cable;iPhone',
#  '34in Ultrawide Monitor;Apple Airpods Headphones',
#  'AAA Batteries (4-pack);Wired Headphones',
#  'iPhone;Lightning Charging Cable',
#  'AAA Batteries (4-pack);Lightning Charging Cable',
#  'USB-C Charging Cable;Wired Headphones;Vareebadd Phone',
#  'iPhone;Lightning Charging Cable',
#  'USB-C Charging Cable;USB-C Charging Cable',
#  'AA Batteries (4-pack);ThinkPad Laptop',
#  'AA Batteries (4-pack);Bose SoundSport Headphones',
#  'Google Phone;Wired Headphones',
#  'Wired Headphones;Vareebadd Phone',
#  'iPhone;Lightning Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'Bose SoundSport Headphones;USB-C Charging Cable',
#  'AA Batteries (4-pack);Google Phone',
#  'AA Batteries (4-pack);Apple Airpods Headphones',
#  'USB-C Charging Cable;USB-C Charging Cable',
#  '27in FHD Monitor;Wired Headphones',
#  'Flatscreen TV;Lightning Charging Cable',
#  'Apple Airpods Headphones;iPhone',
#  'USB-C Charging Cable;Google Phone',
#  'iPhone;Lightning Charging Cable',
#  'iPhone;USB-C Charging Cable',
#  'iPhone;USB-C Charging Cable',
#  'Bose SoundSport Headphones;Google Phone;USB-C Charging Cable',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;27in 4K Gaming Monitor',
#  'iPhone;Lightning Charging Cable',
#  'Google Phone;Wired Headphones',
#  '27in FHD Monitor;Wired Headphones',
#  'Google Phone;Wired Headphones;USB-C Charging Cable',
#  'Lightning Charging Cable;Bose SoundSport Headphones',
#  'iPhone;Lightning Charging Cable',
#  'AAA Batteries (4-pack);USB-C Charging Cable',
#  'Google Phone;USB-C Charging Cable;Wired Headphones',
#  'Lightning Charging Cable;USB-C Charging Cable',
#  'Wired Headphones;Wired Headphones',
#  'iPhone;Wired Headphones',
#  'iPhone;Lightning Charging Cable',
#  'Lightning Charging Cable;iPhone',
#  'iPhone;Lightning Charging Cable',
#  'Google Phone;Apple Airpods Headphones;USB-C Charging Cable',
#  'Google Phone;Flatscreen TV',
#  'Macbook Pro Laptop;iPhone',
#  'iPhone;Lightning Charging Cable',
#  'Apple Airpods Headphones;AAA Batteries (4-pack)',
#  'Google Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'Wired Headphones;USB-C Charging Cable;Google Phone',
#  'Wired Headphones;Google Phone',
#  'iPhone;Wired Headphones',
#  '27in 4K Gaming Monitor;AAA Batteries (4-pack)',
#  'Apple Airpods Headphones;Wired Headphones',
#  'Wired Headphones;Apple Airpods Headphones',
#  'Lightning Charging Cable;Lightning Charging Cable',
#  'iPhone;iPhone;Lightning Charging Cable',
#  'USB-C Charging Cable;USB-C Charging Cable',
#  'iPhone;Wired Headphones',
#  'Lightning Charging Cable;Apple Airpods Headphones;iPhone',
#  'Wired Headphones;Vareebadd Phone',
#  'USB-C Charging Cable;Google Phone',
#  'Wired Headphones;Wired Headphones',
#  'Lightning Charging Cable;iPhone',
#  'Wired Headphones;iPhone',
#  'AAA Batteries (4-pack);Lightning Charging Cable',
#  'Wired Headphones;Google Phone',
#  'Wired Headphones;iPhone',
#  'Lightning Charging Cable;34in Ultrawide Monitor',
#  'iPhone;Lightning Charging Cable',
#  'Apple Airpods Headphones;iPhone',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'Lightning Charging Cable;iPhone',
#  'LG Washing Machine;Google Phone',
#  'Wired Headphones;iPhone',
#  'Google Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;iPhone',
#  'Wired Headphones;LG Washing Machine',
#  'Wired Headphones;iPhone',
#  'AAA Batteries (4-pack);USB-C Charging Cable',
#  '27in FHD Monitor;Macbook Pro Laptop',
#  'Google Phone;USB-C Charging Cable',
#  'Lightning Charging Cable;34in Ultrawide Monitor',
#  'Lightning Charging Cable;Apple Airpods Headphones',
#  'USB-C Charging Cable;Wired Headphones;Google Phone',
#  'USB-C Charging Cable;USB-C Charging Cable',
#  'iPhone;Lightning Charging Cable',
#  'Apple Airpods Headphones;Bose SoundSport Headphones',
#  'Wired Headphones;Wired Headphones',
#  'Google Phone;USB-C Charging Cable',
#  'Macbook Pro Laptop;Bose SoundSport Headphones',
#  'USB-C Charging Cable;Wired Headphones',
#  'Lightning Charging Cable;AA Batteries (4-pack)',
#  'Wired Headphones;iPhone',
#  'Apple Airpods Headphones;iPhone',
#  '20in Monitor;USB-C Charging Cable',
#  'Vareebadd Phone;Bose SoundSport Headphones',
#  'Google Phone;Bose SoundSport Headphones',
#  'USB-C Charging Cable;USB-C Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'Google Phone;iPhone',
#  'Wired Headphones;Google Phone',
#  'USB-C Charging Cable;Google Phone',
#  'Bose SoundSport Headphones;USB-C Charging Cable;Vareebadd Phone',
#  'AAA Batteries (4-pack);Bose SoundSport Headphones',
#  'USB-C Charging Cable;Apple Airpods Headphones',
#  'AAA Batteries (4-pack);34in Ultrawide Monitor',
#  'Apple Airpods Headphones;AAA Batteries (4-pack)',
#  'ThinkPad Laptop;AAA Batteries (4-pack)',
#  'Apple Airpods Headphones;iPhone',
#  'iPhone;Lightning Charging Cable',
#  'Google Phone;USB-C Charging Cable',
#  'Wired Headphones;iPhone',
#  'USB-C Charging Cable;Apple Airpods Headphones',
#  'AAA Batteries (4-pack);Apple Airpods Headphones',
#  'AAA Batteries (4-pack);27in 4K Gaming Monitor',
#  'AAA Batteries (4-pack);Lightning Charging Cable',
#  'iPhone;Lightning Charging Cable;Apple Airpods Headphones',
#  'Bose SoundSport Headphones;Bose SoundSport Headphones',
#  'Apple Airpods Headphones;Lightning Charging Cable',
#  'AA Batteries (4-pack);Apple Airpods Headphones',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'AA Batteries (4-pack);Wired Headphones',
#  'iPhone;AAA Batteries (4-pack)',
#  'Bose SoundSport Headphones;Google Phone',
#  'Apple Airpods Headphones;iPhone',
#  '27in FHD Monitor;Bose SoundSport Headphones',
#  'Bose SoundSport Headphones;Google Phone',
#  'Macbook Pro Laptop;AAA Batteries (4-pack)',
#  'Bose SoundSport Headphones;Flatscreen TV',
#  'Wired Headphones;iPhone',
#  '27in 4K Gaming Monitor;AA Batteries (4-pack)',
#  'Lightning Charging Cable;iPhone',
#  '27in 4K Gaming Monitor;Macbook Pro Laptop',
#  '27in FHD Monitor;Apple Airpods Headphones',
#  'Lightning Charging Cable;iPhone',
#  'Apple Airpods Headphones;iPhone',
#  'Lightning Charging Cable;34in Ultrawide Monitor',
#  'iPhone;Wired Headphones',
#  'Vareebadd Phone;Google Phone',
#  'iPhone;Wired Headphones',
#  'Google Phone;Lightning Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'USB-C Charging Cable;Bose SoundSport Headphones',
#  'Google Phone;Wired Headphones',
#  'ThinkPad Laptop;Bose SoundSport Headphones',
#  'Google Phone;Wired Headphones',
#  'USB-C Charging Cable;Google Phone',
#  'Bose SoundSport Headphones;Google Phone;USB-C Charging Cable',
#  '34in Ultrawide Monitor;Apple Airpods Headphones',
#  'AA Batteries (4-pack);Vareebadd Phone',
#  'Lightning Charging Cable;Bose SoundSport Headphones',
#  'Apple Airpods Headphones;iPhone',
#  'Wired Headphones;Macbook Pro Laptop',
#  'Wired Headphones;Wired Headphones',
#  'Wired Headphones;Wired Headphones',
#  'Google Phone;Bose SoundSport Headphones',
#  'Flatscreen TV;Apple Airpods Headphones',
#  'AAA Batteries (4-pack);Wired Headphones',
#  'iPhone;Lightning Charging Cable',
#  'Wired Headphones;iPhone',
#  'iPhone;Lightning Charging Cable',
#  'Google Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  '27in 4K Gaming Monitor;Lightning Charging Cable',
#  'Wired Headphones;27in FHD Monitor',
#  'USB-C Charging Cable;Google Phone',
#  'Apple Airpods Headphones;Wired Headphones',
#  'Google Phone;USB-C Charging Cable',
#  'iPhone;Apple Airpods Headphones',
#  'Bose SoundSport Headphones;USB-C Charging Cable',
#  'iPhone;Wired Headphones',
#  'Apple Airpods Headphones;AAA Batteries (4-pack)',
#  'Lightning Charging Cable;Wired Headphones',
#  'Apple Airpods Headphones;Lightning Charging Cable',
#  'Google Phone;USB-C Charging Cable',
#  'Google Phone;USB-C Charging Cable;Wired Headphones',
#  'iPhone;Wired Headphones',
#  'Google Phone;Lightning Charging Cable',
#  'Google Phone;27in 4K Gaming Monitor',
#  'Wired Headphones;USB-C Charging Cable;Google Phone',
#  'iPhone;Lightning Charging Cable',
#  '27in 4K Gaming Monitor;Macbook Pro Laptop',
#  'Google Phone;USB-C Charging Cable',
#  'Lightning Charging Cable;27in FHD Monitor',
#  'USB-C Charging Cable;Google Phone',
#  'Lightning Charging Cable;iPhone',
#  'iPhone;Lightning Charging Cable',
#  'iPhone;Lightning Charging Cable',
#  'Google Phone;Wired Headphones',
#  'Bose SoundSport Headphones;Wired Headphones',
#  'AAA Batteries (4-pack);AAA Batteries (4-pack)',
#  'Apple Airpods Headphones;Bose SoundSport Headphones',
#  'Bose SoundSport Headphones;ThinkPad Laptop',
#  'Google Phone;Wired Headphones',
#  'iPhone;Lightning Charging Cable',
#  'iPhone;Wired Headphones',
#  'Apple Airpods Headphones;iPhone',
#  'iPhone;Lightning Charging Cable',
#  'Google Phone;Wired Headphones',
#  '27in FHD Monitor;Bose SoundSport Headphones',
#  'Google Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  '27in 4K Gaming Monitor;Wired Headphones',
#  'USB-C Charging Cable;Google Phone',
#  'Lightning Charging Cable;Apple Airpods Headphones',
#  'USB-C Charging Cable;Google Phone',
#  'Google Phone;USB-C Charging Cable',
#  '34in Ultrawide Monitor;AAA Batteries (4-pack)',
#  'Bose SoundSport Headphones;Lightning Charging Cable',
#  'Google Phone;USB-C Charging Cable;Wired Headphones',
#  'Lightning Charging Cable;Lightning Charging Cable',
#  '27in 4K Gaming Monitor;27in 4K Gaming Monitor',
#  'Apple Airpods Headphones;AA Batteries (4-pack)',
#  'Bose SoundSport Headphones;Google Phone',
#  'USB-C Charging Cable;Google Phone',
#  'iPhone;Wired Headphones',
#  'AA Batteries (4-pack);34in Ultrawide Monitor',
#  'Bose SoundSport Headphones;USB-C Charging Cable;Google Phone',
#  'Lightning Charging Cable;Lightning Charging Cable',
#  'Bose SoundSport Headphones;Google Phone',
#  'Google Phone;Bose SoundSport Headphones;Wired Headphones',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'Lightning Charging Cable;Wired Headphones',
#  'AAA Batteries (4-pack);AA Batteries (4-pack)',
#  'Macbook Pro Laptop;27in FHD Monitor',
#  'iPhone;Lightning Charging Cable',
#  '27in 4K Gaming Monitor;USB-C Charging Cable',
#  'Wired Headphones;iPhone',
#  'USB-C Charging Cable;Google Phone',
#  'Lightning Charging Cable;iPhone',
#  'Wired Headphones;AA Batteries (4-pack)',
#  'Bose SoundSport Headphones;Google Phone',
#  'AAA Batteries (4-pack);Google Phone',
#  '27in 4K Gaming Monitor;AAA Batteries (4-pack)',
#  'Google Phone;USB-C Charging Cable;Bose SoundSport Headphones',
#  'Lightning Charging Cable;iPhone',
#  'Wired Headphones;Google Phone',
#  'Wired Headphones;Google Phone',
#  'ThinkPad Laptop;Wired Headphones',
#  'Google Phone;AA Batteries (4-pack)',
#  'ThinkPad Laptop;Lightning Charging Cable',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'Lightning Charging Cable;iPhone',
#  'iPhone;Lightning Charging Cable',
#  '27in 4K Gaming Monitor;Bose SoundSport Headphones',
#  '27in FHD Monitor;AAA Batteries (4-pack)',
#  'AA Batteries (4-pack);AA Batteries (4-pack)',
#  'iPhone;Wired Headphones',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'Wired Headphones;Vareebadd Phone',
#  '27in 4K Gaming Monitor;Bose SoundSport Headphones',
#  'USB-C Charging Cable;Google Phone',
#  'Google Phone;Wired Headphones',
#  'Apple Airpods Headphones;iPhone',
#  'iPhone;Lightning Charging Cable',
#  'Apple Airpods Headphones;34in Ultrawide Monitor',
#  'Wired Headphones;AA Batteries (4-pack)',
#  'Vareebadd Phone;USB-C Charging Cable',
#  '27in 4K Gaming Monitor;AA Batteries (4-pack)',
#  'Bose SoundSport Headphones;Bose SoundSport Headphones',
#  'Google Phone;Wired Headphones',
#  'Lightning Charging Cable;Bose SoundSport Headphones',
#  'iPhone;Wired Headphones',
#  'USB-C Charging Cable;AA Batteries (4-pack)',
#  'Bose SoundSport Headphones;Vareebadd Phone',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'AAA Batteries (4-pack);AAA Batteries (4-pack)',
#  'Bose SoundSport Headphones;AAA Batteries (4-pack)',
#  'Google Phone;Wired Headphones',
#  'Bose SoundSport Headphones;Apple Airpods Headphones',
#  'Google Phone;Bose SoundSport Headphones',
#  'Bose SoundSport Headphones;AA Batteries (4-pack)',
#  'iPhone;Flatscreen TV',
#  'Lightning Charging Cable;iPhone',
#  'AA Batteries (4-pack);27in FHD Monitor',
#  'Vareebadd Phone;iPhone;Wired Headphones',
#  'Apple Airpods Headphones;AA Batteries (4-pack)',
#  'AAA Batteries (4-pack);Lightning Charging Cable',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'Lightning Charging Cable;iPhone',
#  'USB-C Charging Cable;Google Phone',
#  'USB-C Charging Cable;Google Phone',
#  'Flatscreen TV;AA Batteries (4-pack)',
#  'iPhone;Wired Headphones',
#  'Lightning Charging Cable;27in FHD Monitor',
#  'Wired Headphones;Vareebadd Phone',
#  'Lightning Charging Cable;iPhone',
#  'Lightning Charging Cable;AAA Batteries (4-pack)',
#  'Lightning Charging Cable;Wired Headphones',
#  'iPhone;Apple Airpods Headphones',
#  'AAA Batteries (4-pack);Wired Headphones',
#  'AA Batteries (4-pack);USB-C Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'Wired Headphones;Google Phone',
#  'iPhone;Apple Airpods Headphones',
#  'Lightning Charging Cable;iPhone',
#  'Bose SoundSport Headphones;Google Phone',
#  'Wired Headphones;Google Phone',
#  'Bose SoundSport Headphones;USB-C Charging Cable',
#  'USB-C Charging Cable;iPhone',
#  'USB-C Charging Cable;Wired Headphones;Vareebadd Phone',
#  'USB-C Charging Cable;Google Phone',
#  'USB-C Charging Cable;Google Phone',
#  'iPhone;Lightning Charging Cable',
#  'Wired Headphones;27in 4K Gaming Monitor',
#  'Macbook Pro Laptop;AAA Batteries (4-pack)',
#  'Wired Headphones;iPhone',
#  'Wired Headphones;Macbook Pro Laptop',
#  'Vareebadd Phone;Wired Headphones',
#  'Lightning Charging Cable;USB-C Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'Apple Airpods Headphones;iPhone',
#  'Lightning Charging Cable;34in Ultrawide Monitor',
#  'Google Phone;USB-C Charging Cable',
#  'Google Phone;Wired Headphones',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'Wired Headphones;Vareebadd Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;Lightning Charging Cable',
#  'Wired Headphones;Lightning Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'iPhone;Wired Headphones',
#  'Apple Airpods Headphones;AA Batteries (4-pack)',
#  'iPhone;Wired Headphones',
#  'iPhone;Wired Headphones',
#  'AAA Batteries (4-pack);Apple Airpods Headphones',
#  'Google Phone;USB-C Charging Cable',
#  'Apple Airpods Headphones;iPhone',
#  'Google Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;27in 4K Gaming Monitor',
#  'USB-C Charging Cable;Google Phone',
#  'AA Batteries (4-pack);iPhone',
#  'AAA Batteries (4-pack);USB-C Charging Cable',
#  'iPhone;Lightning Charging Cable',
#  'Apple Airpods Headphones;USB-C Charging Cable',
#  'Lightning Charging Cable;ThinkPad Laptop',
#  '27in FHD Monitor;LG Dryer',
#  'iPhone;Lightning Charging Cable',
#  '20in Monitor;27in FHD Monitor',
#  'Lightning Charging Cable;Google Phone',
#  'Wired Headphones;Lightning Charging Cable',
#  'AAA Batteries (4-pack);Wired Headphones',
#  '20in Monitor;AA Batteries (4-pack)',
#  'USB-C Charging Cable;Google Phone;Bose SoundSport Headphones',
#  'iPhone;Apple Airpods Headphones',
#  'LG Dryer;AA Batteries (4-pack)',
#  'Google Phone;USB-C Charging Cable',
#  'Lightning Charging Cable;iPhone',
#  'AA Batteries (4-pack);AA Batteries (4-pack)',
#  'Lightning Charging Cable;USB-C Charging Cable',
#  '20in Monitor;Apple Airpods Headphones',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'Google Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;27in FHD Monitor',
#  'USB-C Charging Cable;Apple Airpods Headphones',
#  'USB-C Charging Cable;Google Phone',
#  'iPhone;Apple Airpods Headphones',
#  'Wired Headphones;27in 4K Gaming Monitor',
#  'iPhone;Apple Airpods Headphones',
#  'Lightning Charging Cable;AAA Batteries (4-pack)',
#  'Flatscreen TV;Wired Headphones',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'Vareebadd Phone;Apple Airpods Headphones',
#  'Wired Headphones;Bose SoundSport Headphones',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'Apple Airpods Headphones;Lightning Charging Cable',
#  '34in Ultrawide Monitor;34in Ultrawide Monitor',
#  'Google Phone;USB-C Charging Cable',
#  'Wired Headphones;Vareebadd Phone',
#  'USB-C Charging Cable;Google Phone',
#  'Google Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;34in Ultrawide Monitor',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'AA Batteries (4-pack);34in Ultrawide Monitor',
#  'iPhone;Lightning Charging Cable;Wired Headphones',
#  'Wired Headphones;iPhone',
#  'Bose SoundSport Headphones;USB-C Charging Cable',
#  'Google Phone;Lightning Charging Cable',
#  'Flatscreen TV;USB-C Charging Cable',
#  'Google Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'AAA Batteries (4-pack);Wired Headphones',
#  'Vareebadd Phone;Apple Airpods Headphones;Wired Headphones',
#  'Wired Headphones;Google Phone',
#  'USB-C Charging Cable;Google Phone;Wired Headphones',
#  'Flatscreen TV;Apple Airpods Headphones',
#  'USB-C Charging Cable;Google Phone',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'Google Phone;USB-C Charging Cable',
#  '20in Monitor;Macbook Pro Laptop',
#  'Google Phone;Wired Headphones',
#  'Google Phone;USB-C Charging Cable',
#  '27in FHD Monitor;USB-C Charging Cable',
#  'iPhone;Apple Airpods Headphones',
#  'Lightning Charging Cable;USB-C Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'Lightning Charging Cable;Macbook Pro Laptop',
#  'USB-C Charging Cable;AA Batteries (4-pack)',
#  'Lightning Charging Cable;iPhone',
#  'iPhone;Lightning Charging Cable',
#  'Lightning Charging Cable;Apple Airpods Headphones',
#  'iPhone;Lightning Charging Cable',
#  'Vareebadd Phone;Wired Headphones',
#  'Lightning Charging Cable;Lightning Charging Cable',
#  'AA Batteries (4-pack);AAA Batteries (4-pack)',
#  'AA Batteries (4-pack);USB-C Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'Google Phone;USB-C Charging Cable',
#  'AA Batteries (4-pack);AAA Batteries (4-pack)',
#  'iPhone;Wired Headphones',
#  'USB-C Charging Cable;Google Phone',
#  'USB-C Charging Cable;Google Phone',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'USB-C Charging Cable;Apple Airpods Headphones',
#  'AAA Batteries (4-pack);AAA Batteries (4-pack)',
#  'Lightning Charging Cable;iPhone',
#  'USB-C Charging Cable;Google Phone',
#  '27in 4K Gaming Monitor;AA Batteries (4-pack)',
#  'ThinkPad Laptop;AA Batteries (4-pack)',
#  'USB-C Charging Cable;Google Phone',
#  'AA Batteries (4-pack);27in 4K Gaming Monitor',
#  'AA Batteries (4-pack);Bose SoundSport Headphones',
#  'iPhone;Wired Headphones',
#  'iPhone;Wired Headphones',
#  'Lightning Charging Cable;iPhone',
#  'Bose SoundSport Headphones;USB-C Charging Cable',
#  'Lightning Charging Cable;Bose SoundSport Headphones',
#  'Wired Headphones;AA Batteries (4-pack)',
#  'Wired Headphones;Google Phone',
#  'Wired Headphones;Apple Airpods Headphones;Lightning Charging Cable;iPhone;Google Phone',
#  'USB-C Charging Cable;Google Phone',
#  'iPhone;Lightning Charging Cable',
#  'Apple Airpods Headphones;AAA Batteries (4-pack)',
#  'AAA Batteries (4-pack);iPhone',
#  '27in 4K Gaming Monitor;USB-C Charging Cable',
#  '27in 4K Gaming Monitor;Wired Headphones;Vareebadd Phone',
#  'Google Phone;USB-C Charging Cable',
#  'Macbook Pro Laptop;27in 4K Gaming Monitor',
#  'Google Phone;USB-C Charging Cable',
#  'Wired Headphones;iPhone',
#  'Google Phone;Bose SoundSport Headphones',
#  '27in FHD Monitor;34in Ultrawide Monitor',
#  'Lightning Charging Cable;iPhone',
#  'USB-C Charging Cable;Bose SoundSport Headphones',
#  'Lightning Charging Cable;iPhone',
#  'ThinkPad Laptop;iPhone',
#  'Lightning Charging Cable;iPhone',
#  'USB-C Charging Cable;Google Phone',
#  'USB-C Charging Cable;Bose SoundSport Headphones',
#  'AAA Batteries (4-pack);Bose SoundSport Headphones',
#  'AAA Batteries (4-pack);Apple Airpods Headphones',
#  'Wired Headphones;Lightning Charging Cable',
#  '20in Monitor;27in 4K Gaming Monitor',
#  '20in Monitor;Lightning Charging Cable',
#  'Wired Headphones;34in Ultrawide Monitor',
#  'Vareebadd Phone;Bose SoundSport Headphones',
#  'USB-C Charging Cable;Google Phone',
#  'Wired Headphones;Google Phone',
#  'Wired Headphones;Apple Airpods Headphones',
#  'Lightning Charging Cable;Wired Headphones',
#  'iPhone;Lightning Charging Cable',
#  'Bose SoundSport Headphones;Google Phone',
#  'Wired Headphones;Lightning Charging Cable',
#  'iPhone;Lightning Charging Cable',
#  'iPhone;Wired Headphones',
#  'iPhone;Lightning Charging Cable',
#  'Bose SoundSport Headphones;Google Phone',
#  'iPhone;Lightning Charging Cable',
#  'USB-C Charging Cable;34in Ultrawide Monitor',
#  'ThinkPad Laptop;Apple Airpods Headphones',
#  'Lightning Charging Cable;AAA Batteries (4-pack)',
#  'iPhone;Apple Airpods Headphones',
#  'AA Batteries (4-pack);AAA Batteries (4-pack)',
#  'Lightning Charging Cable;Wired Headphones',
#  'LG Washing Machine;Lightning Charging Cable',
#  'Google Phone;AAA Batteries (4-pack);USB-C Charging Cable',
#  '34in Ultrawide Monitor;USB-C Charging Cable',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'USB-C Charging Cable;Google Phone',
#  'iPhone;Lightning Charging Cable;Wired Headphones',
#  'iPhone;Lightning Charging Cable',
#  'USB-C Charging Cable;AA Batteries (4-pack)',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'Wired Headphones;Vareebadd Phone',
#  'USB-C Charging Cable;Google Phone',
#  'Flatscreen TV;AAA Batteries (4-pack)',
#  'Vareebadd Phone;AA Batteries (4-pack)',
#  'AAA Batteries (4-pack);Wired Headphones',
#  'Google Phone;USB-C Charging Cable',
#  'iPhone;Lightning Charging Cable;27in 4K Gaming Monitor',
#  'Macbook Pro Laptop;AAA Batteries (4-pack)',
#  'Google Phone;USB-C Charging Cable',
#  '20in Monitor;Apple Airpods Headphones',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'Flatscreen TV;Flatscreen TV',
#  'Lightning Charging Cable;34in Ultrawide Monitor',
#  'Bose SoundSport Headphones;AAA Batteries (4-pack)',
#  'Vareebadd Phone;Wired Headphones',
#  'Lightning Charging Cable;iPhone',
#  'Lightning Charging Cable;Wired Headphones',
#  'Wired Headphones;iPhone',
#  'AA Batteries (4-pack);iPhone',
#  'Apple Airpods Headphones;iPhone',
#  'Google Phone;Wired Headphones',
#  'Apple Airpods Headphones;Wired Headphones',
#  'Lightning Charging Cable;iPhone',
#  'Lightning Charging Cable;iPhone',
#  'USB-C Charging Cable;Google Phone',
#  'iPhone;Lightning Charging Cable',
#  'Wired Headphones;iPhone',
#  'iPhone;Lightning Charging Cable',
#  'Wired Headphones;USB-C Charging Cable',
#  'AAA Batteries (4-pack);AA Batteries (4-pack)',
#  'Apple Airpods Headphones;Lightning Charging Cable',
#  'Google Phone;USB-C Charging Cable',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'Vareebadd Phone;Wired Headphones',
#  'Bose SoundSport Headphones;Lightning Charging Cable',
#  'Bose SoundSport Headphones;Apple Airpods Headphones',
#  'Apple Airpods Headphones;iPhone',
#  'Apple Airpods Headphones;USB-C Charging Cable',
#  'iPhone;Lightning Charging Cable',
#  '34in Ultrawide Monitor;AA Batteries (4-pack)',
#  'Bose SoundSport Headphones;Google Phone',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'iPhone;Lightning Charging Cable',
#  'Wired Headphones;Google Phone',
#  'USB-C Charging Cable;Google Phone',
#  'AAA Batteries (4-pack);AAA Batteries (4-pack)',
#  'Lightning Charging Cable;34in Ultrawide Monitor',
#  'iPhone;Lightning Charging Cable',
#  'Lightning Charging Cable;USB-C Charging Cable',
#  'iPhone;Lightning Charging Cable',
#  'Google Phone;Bose SoundSport Headphones;USB-C Charging Cable',
#  'ThinkPad Laptop;Wired Headphones',
#  'Flatscreen TV;Wired Headphones',
#  'USB-C Charging Cable;Vareebadd Phone',
#  'USB-C Charging Cable;34in Ultrawide Monitor',
#  'Wired Headphones;iPhone',
#  'Bose SoundSport Headphones;27in FHD Monitor',
#  'Google Phone;Bose SoundSport Headphones',
#  'Wired Headphones;Apple Airpods Headphones',
#  'Google Phone;USB-C Charging Cable',
#  'Lightning Charging Cable;iPhone;Apple Airpods Headphones',
#  'Lightning Charging Cable;iPhone',
#  'Bose SoundSport Headphones;Vareebadd Phone',
#  'Apple Airpods Headphones;Macbook Pro Laptop',
#  'USB-C Charging Cable;AA Batteries (4-pack)',
#  'AA Batteries (4-pack);AA Batteries (4-pack)',
#  'Lightning Charging Cable;iPhone',
#  'USB-C Charging Cable;Google Phone',
#  'Apple Airpods Headphones;iPhone',
#  'Google Phone;USB-C Charging Cable',
#  'Wired Headphones;Vareebadd Phone',
#  'Google Phone;USB-C Charging Cable',
#  '27in FHD Monitor;Apple Airpods Headphones',
#  '27in FHD Monitor;34in Ultrawide Monitor',
#  'iPhone;Lightning Charging Cable',
#  'AAA Batteries (4-pack);Lightning Charging Cable',
#  'Flatscreen TV;Bose SoundSport Headphones',
#  'USB-C Charging Cable;iPhone',
#  'USB-C Charging Cable;Lightning Charging Cable',
#  'Google Phone;Wired Headphones',
#  'Vareebadd Phone;27in 4K Gaming Monitor',
#  'USB-C Charging Cable;Google Phone',
#  'Bose SoundSport Headphones;Bose SoundSport Headphones',
#  'Lightning Charging Cable;AAA Batteries (4-pack)',
#  'USB-C Charging Cable;AA Batteries (4-pack)',
#  'Google Phone;USB-C Charging Cable',
#  '34in Ultrawide Monitor;AA Batteries (4-pack)',
#  'Flatscreen TV;Lightning Charging Cable',
#  'Lightning Charging Cable;iPhone',
#  'AAA Batteries (4-pack);Wired Headphones',
#  'Apple Airpods Headphones;20in Monitor',
#  'Lightning Charging Cable;iPhone',
#  'Wired Headphones;iPhone',
#  'Wired Headphones;Lightning Charging Cable;iPhone',
#  'iPhone;Wired Headphones',
#  'Lightning Charging Cable;Bose SoundSport Headphones',
#  'Lightning Charging Cable;iPhone',
#  'Wired Headphones;Google Phone',
#  'Wired Headphones;AAA Batteries (4-pack)',
#  'Google Phone;USB-C Charging Cable',
#  'Bose SoundSport Headphones;Flatscreen TV',
#  'Google Phone;USB-C Charging Cable',
#  'AA Batteries (4-pack);Bose SoundSport Headphones',
#  'AAA Batteries (4-pack);USB-C Charging Cable',
#  'AAA Batteries (4-pack);USB-C Charging Cable',
#  'Lightning Charging Cable;34in Ultrawide Monitor',
#  'AAA Batteries (4-pack);USB-C Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'Bose SoundSport Headphones;Google Phone;USB-C Charging Cable',
#  'Bose SoundSport Headphones;Apple Airpods Headphones',
#  'Google Phone;Bose SoundSport Headphones',
#  'AAA Batteries (4-pack);AA Batteries (4-pack)',
#  'USB-C Charging Cable;Google Phone',
#  'AA Batteries (4-pack);34in Ultrawide Monitor',
#  'USB-C Charging Cable;Google Phone',
#  'USB-C Charging Cable;Google Phone',
#  'Google Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;Google Phone',
#  'Bose SoundSport Headphones;Apple Airpods Headphones',
#  'Lightning Charging Cable;Lightning Charging Cable',
#  'Lightning Charging Cable;Macbook Pro Laptop',
#  'Vareebadd Phone;Wired Headphones',
#  'AA Batteries (4-pack);Apple Airpods Headphones',
#  'AA Batteries (4-pack);Lightning Charging Cable',
#  'iPhone;Lightning Charging Cable',
#  'Wired Headphones;Google Phone',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'Google Phone;AA Batteries (4-pack)',
#  'Bose SoundSport Headphones;Google Phone',
#  'Apple Airpods Headphones;USB-C Charging Cable',
#  'Lightning Charging Cable;Wired Headphones',
#  'iPhone;USB-C Charging Cable',
#  'Lightning Charging Cable;iPhone',
#  'Lightning Charging Cable;Lightning Charging Cable',
#  'USB-C Charging Cable;ThinkPad Laptop',
#  'Google Phone;USB-C Charging Cable',
#  'iPhone;AA Batteries (4-pack)',
#  '27in FHD Monitor;Lightning Charging Cable',
#  'Google Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;AAA Batteries (4-pack)',
#  'Google Phone;Wired Headphones',
#  'AAA Batteries (4-pack);Wired Headphones',
#  'Apple Airpods Headphones;Apple Airpods Headphones',
#  'Lightning Charging Cable;iPhone',
#  'Apple Airpods Headphones;Lightning Charging Cable',
#  'iPhone;Apple Airpods Headphones',
#  'AA Batteries (4-pack);Wired Headphones;USB-C Charging Cable;Google Phone',
#  '34in Ultrawide Monitor;34in Ultrawide Monitor',
#  'AAA Batteries (4-pack);AAA Batteries (4-pack)',
#  'Wired Headphones;AAA Batteries (4-pack)',
#  'iPhone;Lightning Charging Cable',
#  'AA Batteries (4-pack);Vareebadd Phone',
#  'Bose SoundSport Headphones;Wired Headphones',
#  'Lightning Charging Cable;iPhone',
#  '27in FHD Monitor;Google Phone',
#  'Wired Headphones;Apple Airpods Headphones',
#  'AA Batteries (4-pack);Wired Headphones',
#  'iPhone;Lightning Charging Cable',
#  'Wired Headphones;Vareebadd Phone',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'USB-C Charging Cable;USB-C Charging Cable',
#  'Wired Headphones;USB-C Charging Cable;Google Phone',
#  '34in Ultrawide Monitor;Bose SoundSport Headphones',
#  'Vareebadd Phone;USB-C Charging Cable',
#  'Apple Airpods Headphones;iPhone',
#  'Google Phone;Wired Headphones',
#  'iPhone;Lightning Charging Cable',
#  'Wired Headphones;Google Phone',
#  'Lightning Charging Cable;AAA Batteries (4-pack)',
#  'Lightning Charging Cable;USB-C Charging Cable',
#  'Lightning Charging Cable;ThinkPad Laptop',
#  'Wired Headphones;iPhone',
#  'Vareebadd Phone;27in FHD Monitor',
#  'Google Phone;Bose SoundSport Headphones',
#  'USB-C Charging Cable;Google Phone',
#  'Wired Headphones;Vareebadd Phone',
#  'Wired Headphones;Lightning Charging Cable',
#  'Wired Headphones;Apple Airpods Headphones',
#  '27in FHD Monitor;Wired Headphones',
#  'Lightning Charging Cable;Apple Airpods Headphones',
#  'Google Phone;USB-C Charging Cable',
#  'iPhone;Lightning Charging Cable',
#  'AAA Batteries (4-pack);iPhone',
#  ...]

# %%
for achat in ensemble.to_list():
    products = achat.split(';')
    #print(products)
    count.update(Counter(combinations(products, 2)))

# %%
count
# Out:
# Counter({('USB-C Charging Cable', 'Wired Headphones'): 107,
#          ('Apple Airpods Headphones', 'AA Batteries (4-pack)'): 29,
#          ('Wired Headphones', 'Vareebadd Phone'): 78,
#          ('Google Phone', 'USB-C Charging Cable'): 476,
#          ('Google Phone', 'Bose SoundSport Headphones'): 124,
#          ('iPhone', 'Apple Airpods Headphones'): 177,
#          ('Apple Airpods Headphones', 'Google Phone'): 13,
#          ('Apple Airpods Headphones', 'iPhone'): 178,
#          ('Apple Airpods Headphones', 'Wired Headphones'): 52,
#          ('iPhone', 'Wired Headphones'): 233,
#          ('USB-C Charging Cable', 'Apple Airpods Headphones'): 31,
#          ('Lightning Charging Cable', 'Wired Headphones'): 65,
#          ('Lightning Charging Cable', 'iPhone'): 478,
#          ('Bose SoundSport Headphones', '27in FHD Monitor'): 13,
#          ('USB-C Charging Cable', 'Google Phone'): 490,
#          ('Wired Headphones', 'iPhone'): 219,
#          ('AAA Batteries (4-pack)', 'AA Batteries (4-pack)'): 47,
#          ('Wired Headphones', 'USB-C Charging Cable'): 91,
#          ('USB-C Charging Cable', 'Vareebadd Phone'): 184,
#          ('Vareebadd Phone', 'Wired Headphones'): 69,
#          ('Lightning Charging Cable', '34in Ultrawide Monitor'): 15,
#          ('Bose SoundSport Headphones', 'Lightning Charging Cable'): 32,
#          ('Wired Headphones', 'Google Phone'): 198,
#          ('Lightning Charging Cable', 'Apple Airpods Headphones'): 57,
#          ('Google Phone', 'iPhone'): 5,
#          ('iPhone', 'Lightning Charging Cable'): 505,
#          ('20in Monitor', 'Wired Headphones'): 7,
#          ('Google Phone', 'Wired Headphones'): 212,
#          ('AA Batteries (4-pack)', 'AA Batteries (4-pack)'): 35,
#          ('20in Monitor', 'Bose SoundSport Headphones'): 12,
#          ('Wired Headphones', 'Bose SoundSport Headphones'): 34,
#          ('Bose SoundSport Headphones', 'Google Phone'): 103,
#          ('Apple Airpods Headphones', 'USB-C Charging Cable'): 31,
#          ('iPhone', 'Google Phone'): 4,
#          ('Vareebadd Phone', 'USB-C Charging Cable'): 170,
#          ('Vareebadd Phone', 'Bose SoundSport Headphones'): 43,
#          ('AA Batteries (4-pack)', 'AAA Batteries (4-pack)'): 39,
#          ('AAA Batteries (4-pack)', '27in 4K Gaming Monitor'): 12,
#          ('AA Batteries (4-pack)', 'USB-C Charging Cable'): 31,
#          ('USB-C Charging Cable', 'Lightning Charging Cable'): 50,
#          ('AA Batteries (4-pack)', 'Macbook Pro Laptop'): 10,
#          ('Bose SoundSport Headphones', 'Macbook Pro Laptop'): 8,
#          ('Wired Headphones', '34in Ultrawide Monitor'): 17,
#          ('Bose SoundSport Headphones', 'Wired Headphones'): 38,
#          ('Wired Headphones', 'AA Batteries (4-pack)'): 35,
#          ('20in Monitor', 'USB-C Charging Cable'): 14,
#          ('Bose SoundSport Headphones', 'Apple Airpods Headphones'): 28,
#          ('Wired Headphones', 'Lightning Charging Cable'): 63,
#          ('ThinkPad Laptop', 'Wired Headphones'): 6,
#          ('LG Dryer', 'Flatscreen TV'): 1,
#          ('Apple Airpods Headphones', 'AAA Batteries (4-pack)'): 37,
#          ('AA Batteries (4-pack)', 'Bose SoundSport Headphones'): 31,
#          ('34in Ultrawide Monitor', 'Lightning Charging Cable'): 17,
#          ('ThinkPad Laptop', 'Apple Airpods Headphones'): 6,
#          ('Flatscreen TV', 'AAA Batteries (4-pack)'): 11,
#          ('USB-C Charging Cable', 'AAA Batteries (4-pack)'): 51,
#          ('USB-C Charging Cable', '27in FHD Monitor'): 21,
#          ('27in 4K Gaming Monitor', 'AA Batteries (4-pack)'): 15,
#          ('AA Batteries (4-pack)', 'Wired Headphones'): 46,
#          ('iPhone', '27in 4K Gaming Monitor'): 7,
#          ('AAA Batteries (4-pack)', 'Lightning Charging Cable'): 41,
#          ('Lightning Charging Cable', 'USB-C Charging Cable'): 49,
#          ('27in FHD Monitor', 'Lightning Charging Cable'): 14,
#          ('USB-C Charging Cable', 'Flatscreen TV'): 9,
#          ('LG Washing Machine', 'Bose SoundSport Headphones'): 1,
#          ('Lightning Charging Cable', 'Macbook Pro Laptop'): 12,
#          ('iPhone', 'USB-C Charging Cable'): 16,
#          ('AA Batteries (4-pack)', 'Lightning Charging Cable'): 44,
#          ('Wired Headphones', '20in Monitor'): 11,
#          ('AA Batteries (4-pack)', '27in 4K Gaming Monitor'): 10,
#          ('Bose SoundSport Headphones', 'Vareebadd Phone'): 33,
#          ('AA Batteries (4-pack)', 'LG Dryer'): 1,
#          ('USB-C Charging Cable', 'Bose SoundSport Headphones'): 57,
#          ('Lightning Charging Cable', 'Lightning Charging Cable'): 53,
#          ('Vareebadd Phone', 'AAA Batteries (4-pack)'): 4,
#          ('Apple Airpods Headphones', 'Flatscreen TV'): 5,
#          ('AAA Batteries (4-pack)', 'Wired Headphones'): 42,
#          ('AAA Batteries (4-pack)', 'Bose SoundSport Headphones'): 28,
#          ('AAA Batteries (4-pack)', 'Flatscreen TV'): 9,
#          ('Wired Headphones', 'ThinkPad Laptop'): 8,
#          ('Lightning Charging Cable', 'Flatscreen TV'): 8,
#          ('USB-C Charging Cable', 'iPhone'): 13,
#          ('Wired Headphones', 'AAA Batteries (4-pack)'): 42,
#          ('Lightning Charging Cable', 'Google Phone'): 13,
#          ('Flatscreen TV', 'AA Batteries (4-pack)'): 9,
#          ('Lightning Charging Cable', 'AA Batteries (4-pack)'): 58,
#          ('Flatscreen TV', '34in Ultrawide Monitor'): 3,
#          ('27in FHD Monitor', 'AAA Batteries (4-pack)'): 17,
#          ('LG Dryer', 'AA Batteries (4-pack)'): 5,
#          ('Flatscreen TV', 'Apple Airpods Headphones'): 8,
#          ('Apple Airpods Headphones', 'Lightning Charging Cable'): 54,
#          ('Google Phone', 'Google Phone'): 3,
#          ('27in FHD Monitor', '27in 4K Gaming Monitor'): 5,
#          ('AA Batteries (4-pack)', '34in Ultrawide Monitor'): 14,
#          ('Flatscreen TV', 'Wired Headphones'): 8,
#          ('AAA Batteries (4-pack)', '27in FHD Monitor'): 23,
#          ('USB-C Charging Cable', '20in Monitor'): 11,
#          ('27in 4K Gaming Monitor', 'USB-C Charging Cable'): 8,
#          ('AAA Batteries (4-pack)', '34in Ultrawide Monitor'): 13,
#          ('Wired Headphones', 'Wired Headphones'): 35,
#          ('Bose SoundSport Headphones', 'USB-C Charging Cable'): 44,
#          ('Google Phone', 'AA Batteries (4-pack)'): 11,
#          ('USB-C Charging Cable', 'AA Batteries (4-pack)'): 42,
#          ('Apple Airpods Headphones', 'Macbook Pro Laptop'): 9,
#          ('USB-C Charging Cable', '34in Ultrawide Monitor'): 15,
#          ('20in Monitor', 'Lightning Charging Cable'): 12,
#          ('Bose SoundSport Headphones', 'AA Batteries (4-pack)'): 20,
#          ('AAA Batteries (4-pack)', 'Apple Airpods Headphones'): 40,
#          ('ThinkPad Laptop', 'USB-C Charging Cable'): 11,
#          ('Macbook Pro Laptop', 'Bose SoundSport Headphones'): 7,
#          ('Bose SoundSport Headphones', '27in 4K Gaming Monitor'): 12,
#          ('USB-C Charging Cable', 'USB-C Charging Cable'): 46,
#          ('AA Batteries (4-pack)', 'Flatscreen TV'): 11,
#          ('Lightning Charging Cable', '27in 4K Gaming Monitor'): 13,
#          ('Apple Airpods Headphones', 'Apple Airpods Headphones'): 23,
#          ('27in FHD Monitor', 'Apple Airpods Headphones'): 9,
#          ('34in Ultrawide Monitor', 'Apple Airpods Headphones'): 8,
#          ('AA Batteries (4-pack)', 'ThinkPad Laptop'): 9,
#          ('AA Batteries (4-pack)', 'Google Phone'): 13,
#          ('AA Batteries (4-pack)', 'Apple Airpods Headphones'): 39,
#          ('27in FHD Monitor', 'Wired Headphones'): 11,
#          ('Flatscreen TV', 'Lightning Charging Cable'): 12,
#          ('USB-C Charging Cable', '27in 4K Gaming Monitor'): 13,
#          ('Lightning Charging Cable', 'Bose SoundSport Headphones'): 36,
#          ('AAA Batteries (4-pack)', 'USB-C Charging Cable'): 41,
#          ('Google Phone', 'Apple Airpods Headphones'): 8,
#          ('Google Phone', 'Flatscreen TV'): 2,
#          ('Macbook Pro Laptop', 'iPhone'): 3,
#          ('27in 4K Gaming Monitor', 'AAA Batteries (4-pack)'): 17,
#          ('Wired Headphones', 'Apple Airpods Headphones'): 46,
#          ('iPhone', 'iPhone'): 2,
#          ('LG Washing Machine', 'Google Phone'): 1,
#          ('Wired Headphones', 'LG Washing Machine'): 4,
#          ('27in FHD Monitor', 'Macbook Pro Laptop'): 2,
#          ('Apple Airpods Headphones', 'Bose SoundSport Headphones'): 22,
#          ('ThinkPad Laptop', 'AAA Batteries (4-pack)'): 11,
#          ('Bose SoundSport Headphones', 'Bose SoundSport Headphones'): 27,
#          ('iPhone', 'AAA Batteries (4-pack)'): 15,
#          ('27in FHD Monitor', 'Bose SoundSport Headphones'): 13,
#          ('Macbook Pro Laptop', 'AAA Batteries (4-pack)'): 11,
#          ('Bose SoundSport Headphones', 'Flatscreen TV'): 6,
#          ('27in 4K Gaming Monitor', 'Macbook Pro Laptop'): 7,
#          ('Vareebadd Phone', 'Google Phone'): 3,
#          ('Google Phone', 'Lightning Charging Cable'): 15,
#          ('ThinkPad Laptop', 'Bose SoundSport Headphones'): 6,
#          ('AA Batteries (4-pack)', 'Vareebadd Phone'): 6,
#          ('Wired Headphones', 'Macbook Pro Laptop'): 17,
#          ('27in 4K Gaming Monitor', 'Lightning Charging Cable'): 19,
#          ('Wired Headphones', '27in FHD Monitor'): 11,
#          ('Google Phone', '27in 4K Gaming Monitor'): 6,
#          ('Lightning Charging Cable', '27in FHD Monitor'): 22,
#          ('AAA Batteries (4-pack)', 'AAA Batteries (4-pack)'): 46,
#          ('Bose SoundSport Headphones', 'ThinkPad Laptop'): 6,
#          ('27in 4K Gaming Monitor', 'Wired Headphones'): 12,
#          ('34in Ultrawide Monitor', 'AAA Batteries (4-pack)'): 11,
#          ('27in 4K Gaming Monitor', '27in 4K Gaming Monitor'): 5,
#          ('Macbook Pro Laptop', '27in FHD Monitor'): 5,
#          ('AAA Batteries (4-pack)', 'Google Phone'): 11,
#          ('ThinkPad Laptop', 'Lightning Charging Cable'): 8,
#          ('27in 4K Gaming Monitor', 'Bose SoundSport Headphones'): 6,
#          ('Apple Airpods Headphones', '34in Ultrawide Monitor'): 5,
#          ('Bose SoundSport Headphones', 'AAA Batteries (4-pack)'): 27,
#          ('iPhone', 'Flatscreen TV'): 7,
#          ('AA Batteries (4-pack)', '27in FHD Monitor'): 16,
#          ('Vareebadd Phone', 'iPhone'): 3,
#          ('Lightning Charging Cable', 'AAA Batteries (4-pack)'): 38,
#          ('Wired Headphones', '27in 4K Gaming Monitor'): 15,
#          ('AA Batteries (4-pack)', 'iPhone'): 15,
#          ('Lightning Charging Cable', 'ThinkPad Laptop'): 10,
#          ('27in FHD Monitor', 'LG Dryer'): 2,
#          ('20in Monitor', '27in FHD Monitor'): 1,
#          ('20in Monitor', 'AA Batteries (4-pack)'): 4,
#          ('20in Monitor', 'Apple Airpods Headphones'): 3,
#          ('Vareebadd Phone', 'Apple Airpods Headphones'): 6,
#          ('34in Ultrawide Monitor', '34in Ultrawide Monitor'): 7,
#          ('Flatscreen TV', 'USB-C Charging Cable'): 8,
#          ('20in Monitor', 'Macbook Pro Laptop'): 4,
#          ('27in FHD Monitor', 'USB-C Charging Cable'): 22,
#          ('ThinkPad Laptop', 'AA Batteries (4-pack)'): 8,
#          ('AAA Batteries (4-pack)', 'iPhone'): 13,
#          ('27in 4K Gaming Monitor', 'Vareebadd Phone'): 1,
#          ('Macbook Pro Laptop', '27in 4K Gaming Monitor'): 5,
#          ('27in FHD Monitor', '34in Ultrawide Monitor'): 4,
#          ('ThinkPad Laptop', 'iPhone'): 3,
#          ('20in Monitor', '27in 4K Gaming Monitor'): 2,
#          ('LG Washing Machine', 'Lightning Charging Cable'): 4,
#          ('Google Phone', 'AAA Batteries (4-pack)'): 11,
#          ('34in Ultrawide Monitor', 'USB-C Charging Cable'): 11,
#          ('Vareebadd Phone', 'AA Batteries (4-pack)'): 5,
#          ('Flatscreen TV', 'Flatscreen TV'): 6,
#          ('34in Ultrawide Monitor', 'AA Batteries (4-pack)'): 18,
#          ('Flatscreen TV', 'Bose SoundSport Headphones'): 6,
#          ('Vareebadd Phone', '27in 4K Gaming Monitor'): 2,
#          ('Apple Airpods Headphones', '20in Monitor'): 9,
#          ('USB-C Charging Cable', 'ThinkPad Laptop'): 9,
#          ('iPhone', 'AA Batteries (4-pack)'): 16,
#          ('27in FHD Monitor', 'Google Phone'): 3,
#          ('34in Ultrawide Monitor', 'Bose SoundSport Headphones'): 7,
#          ('Vareebadd Phone', '27in FHD Monitor'): 1,
#          ('LG Washing Machine', '27in 4K Gaming Monitor'): 1,
#          ('Flatscreen TV', 'ThinkPad Laptop'): 2,
#          ('AAA Batteries (4-pack)', 'ThinkPad Laptop'): 16,
#          ('27in 4K Gaming Monitor', 'Apple Airpods Headphones'): 8,
#          ('Flatscreen TV', '27in 4K Gaming Monitor'): 3,
#          ('Macbook Pro Laptop', 'Lightning Charging Cable'): 9,
#          ('27in FHD Monitor', '27in FHD Monitor'): 9,
#          ('Bose SoundSport Headphones', 'iPhone'): 6,
#          ('Lightning Charging Cable', '20in Monitor'): 12,
#          ('Vareebadd Phone', 'ThinkPad Laptop'): 2,
#          ('Google Phone', '34in Ultrawide Monitor'): 3,
#          ('Apple Airpods Headphones', 'ThinkPad Laptop'): 10,
#          ('AAA Batteries (4-pack)', 'LG Washing Machine'): 4,
#          ('LG Washing Machine', 'Apple Airpods Headphones'): 1,
#          ('34in Ultrawide Monitor', '27in 4K Gaming Monitor'): 3,
#          ('34in Ultrawide Monitor', '27in FHD Monitor'): 6,
#          ('27in 4K Gaming Monitor', 'Flatscreen TV'): 2,
#          ('20in Monitor', '20in Monitor'): 3,
#          ('Flatscreen TV', '27in FHD Monitor'): 2,
#          ('Macbook Pro Laptop', 'Wired Headphones'): 2,
#          ('Apple Airpods Headphones', '27in FHD Monitor'): 15,
#          ('27in 4K Gaming Monitor', 'LG Dryer'): 1,
#          ('LG Washing Machine', '20in Monitor'): 2,
#          ('Apple Airpods Headphones', 'LG Dryer'): 2,
#          ('LG Dryer', 'Google Phone'): 1,
#          ('AAA Batteries (4-pack)', '20in Monitor'): 6,
#          ('Macbook Pro Laptop', 'ThinkPad Laptop'): 2,
#          ('34in Ultrawide Monitor', 'Macbook Pro Laptop'): 4,
#          ('Macbook Pro Laptop', 'Apple Airpods Headphones'): 7,
#          ('Apple Airpods Headphones', '27in 4K Gaming Monitor'): 13,
#          ('LG Dryer', 'Lightning Charging Cable'): 1,
#          ('Lightning Charging Cable', 'Vareebadd Phone'): 3,
#          ('iPhone', 'Vareebadd Phone'): 4,
#          ('Macbook Pro Laptop', 'AA Batteries (4-pack)'): 7,
#          ('iPhone', '34in Ultrawide Monitor'): 8,
#          ('Bose SoundSport Headphones', '20in Monitor'): 3,
#          ('iPhone', 'Bose SoundSport Headphones'): 6,
#          ('Apple Airpods Headphones', 'Vareebadd Phone'): 5,
#          ('Vareebadd Phone', '34in Ultrawide Monitor'): 2,
#          ('27in FHD Monitor', 'AA Batteries (4-pack)'): 10,
#          ('Google Phone', '27in FHD Monitor'): 5,
#          ('iPhone', '27in FHD Monitor'): 1,
#          ('27in 4K Gaming Monitor', '34in Ultrawide Monitor'): 3,
#          ('AAA Batteries (4-pack)', 'Macbook Pro Laptop'): 6,
#          ('USB-C Charging Cable', 'Macbook Pro Laptop'): 8,
#          ('ThinkPad Laptop', 'Macbook Pro Laptop'): 2,
#          ('34in Ultrawide Monitor', 'Google Phone'): 2,
#          ('27in FHD Monitor', 'Flatscreen TV'): 3,
#          ('34in Ultrawide Monitor', 'iPhone'): 5,
#          ('Google Phone', 'ThinkPad Laptop'): 3,
#          ('iPhone', 'ThinkPad Laptop'): 3,
#          ('Bose SoundSport Headphones', '34in Ultrawide Monitor'): 9,
#          ('20in Monitor', 'AAA Batteries (4-pack)'): 4,
#          ('27in FHD Monitor', 'Vareebadd Phone'): 1,
#          ('27in 4K Gaming Monitor', 'ThinkPad Laptop'): 4,
#          ('AA Batteries (4-pack)', '20in Monitor'): 11,
#          ('27in FHD Monitor', 'ThinkPad Laptop'): 4,
#          ('Flatscreen TV', '20in Monitor'): 2,
#          ('LG Dryer', 'Apple Airpods Headphones'): 1,
#          ('34in Ultrawide Monitor', 'Wired Headphones'): 11,
#          ('LG Dryer', 'USB-C Charging Cable'): 1,
#          ('Macbook Pro Laptop', 'Macbook Pro Laptop'): 2,
#          ('Flatscreen TV', 'Macbook Pro Laptop'): 2,
#          ('Macbook Pro Laptop', '20in Monitor'): 2,
#          ('Flatscreen TV', 'Google Phone'): 2,
#          ('iPhone', 'Macbook Pro Laptop'): 3,
#          ('Flatscreen TV', 'iPhone'): 3,
#          ('27in 4K Gaming Monitor', '27in FHD Monitor'): 3,
#          ('ThinkPad Laptop', '27in 4K Gaming Monitor'): 1,
#          ('ThinkPad Laptop', 'Google Phone'): 2,
#          ('LG Washing Machine', '34in Ultrawide Monitor'): 1,
#          ('Macbook Pro Laptop', 'Google Phone'): 2,
#          ('Google Phone', 'Vareebadd Phone'): 2,
#          ('34in Ultrawide Monitor', 'Flatscreen TV'): 4,
#          ('LG Washing Machine', 'iPhone'): 2,
#          ('27in 4K Gaming Monitor', 'iPhone'): 2,
#          ('Macbook Pro Laptop', 'USB-C Charging Cable'): 10,
#          ('Wired Headphones', 'Flatscreen TV'): 2,
#          ('Wired Headphones', 'LG Dryer'): 1,
#          ('ThinkPad Laptop', 'Flatscreen TV'): 4,
#          ('27in FHD Monitor', 'LG Washing Machine'): 1,
#          ('34in Ultrawide Monitor', '20in Monitor'): 2,
#          ('Google Phone', 'Macbook Pro Laptop'): 5,
#          ('AAA Batteries (4-pack)', 'Vareebadd Phone'): 2,
#          ('Google Phone', '20in Monitor'): 2,
#          ('Lightning Charging Cable', 'LG Washing Machine'): 2,
#          ('Bose SoundSport Headphones', 'LG Washing Machine'): 1,
#          ('34in Ultrawide Monitor', 'Vareebadd Phone'): 2,
#          ('Vareebadd Phone', 'Flatscreen TV'): 2,
#          ('Macbook Pro Laptop', 'Flatscreen TV'): 2,
#          ('Lightning Charging Cable', 'LG Dryer'): 2,
#          ('20in Monitor', 'iPhone'): 1,
#          ('LG Washing Machine', 'Macbook Pro Laptop'): 2,
#          ('34in Ultrawide Monitor', 'ThinkPad Laptop'): 2,
#          ('LG Dryer', 'Vareebadd Phone'): 1,
#          ('20in Monitor', 'Google Phone'): 2,
#          ('ThinkPad Laptop', 'LG Dryer'): 1,
#          ('LG Washing Machine', 'AA Batteries (4-pack)'): 1,
#          ('20in Monitor', 'ThinkPad Laptop'): 2,
#          ('ThinkPad Laptop', '27in FHD Monitor'): 2,
#          ('ThinkPad Laptop', '34in Ultrawide Monitor'): 2,
#          ('AAA Batteries (4-pack)', 'LG Dryer'): 1,
#          ('27in FHD Monitor', '20in Monitor'): 3,
#          ('Flatscreen TV', 'Vareebadd Phone'): 1,
#          ('Macbook Pro Laptop', '34in Ultrawide Monitor'): 3,
#          ('LG Dryer', 'AAA Batteries (4-pack)'): 1,
#          ('LG Dryer', '27in 4K Gaming Monitor'): 1,
#          ('iPhone', '20in Monitor'): 1,
#          ('Vareebadd Phone', 'Lightning Charging Cable'): 1,
#          ('ThinkPad Laptop', 'ThinkPad Laptop'): 2})

# %%
count.most_common(1)
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 505)]

# %%
for ensemble, c in count.most_common(10):
    print(ensemble, c)
# Out:
# ('iPhone', 'Lightning Charging Cable') 505
# ('USB-C Charging Cable', 'Google Phone') 490
# ('Lightning Charging Cable', 'iPhone') 478
# ('Google Phone', 'USB-C Charging Cable') 476
# ('iPhone', 'Wired Headphones') 233
# ('Wired Headphones', 'iPhone') 219
# ('Google Phone', 'Wired Headphones') 212
# ('Wired Headphones', 'Google Phone') 198
# ('USB-C Charging Cable', 'Vareebadd Phone') 184
# ('Apple Airpods Headphones', 'iPhone') 178

# %%
df_clean.groupby('Product')['Quantity Ordered'].sum().sort_values(ascending=False)
# Out:
# Product
# AAA Batteries (4-pack)        30487
# AA Batteries (4-pack)         27148
# USB-C Charging Cable          23555
# Lightning Charging Cable      22841
# Wired Headphones              20201
# Apple Airpods Headphones      15383
# Bose SoundSport Headphones    13236
# 27in FHD Monitor               7429
# iPhone                         6732
# 27in 4K Gaming Monitor         6134
# 34in Ultrawide Monitor         6076
# Google Phone                   5440
# Flatscreen TV                  4724
# Macbook Pro Laptop             4645
# 20in Monitor                   4058
# ThinkPad Laptop                4054
# Vareebadd Phone                2023
# LG Washing Machine              649
# LG Dryer                        640
# Name: Quantity Ordered, dtype: int64

# %%
from sqlite3 import connect
conn = connect('elieze.db')
df=pd.read_sql_query("select * from user", conn)
#df = pd.DataFrame()

#df_f = pd.read_sql('user', 'mysql:///elieze.sql')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:2020, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2019 try:
# -> 2020     cur.execute(*args, **kwargs)
#    2021     return cur
#
# OperationalError: no such table: user
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Input In [6], in <cell line: 3>()
#       1 from sqlite3 import connect
#       2 conn = connect('elieze.db')
# ----> 3 df=pd.read_sql_query("select * from user", conn)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:399, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     341 """
#     342 Read SQL query into a DataFrame.
#     343
#    (...)
#     396 parameter will be converted to UTC.
#     397 """
#     398 pandas_sql = pandasSQL_builder(con)
# --> 399 return pandas_sql.read_query(
#     400     sql,
#     401     index_col=index_col,
#     402     params=params,
#     403     coerce_float=coerce_float,
#     404     parse_dates=parse_dates,
#     405     chunksize=chunksize,
#     406     dtype=dtype,
#     407 )
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:2080, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2068 def read_query(
#    2069     self,
#    2070     sql,
#    (...)
#    2076     dtype: DtypeArg | None = None,
#    2077 ):
#    2079     args = _convert_params(sql, params)
# -> 2080     cursor = self.execute(*args)
#    2081     columns = [col_desc[0] for col_desc in cursor.description]
#    2083     if chunksize is not None:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:2032, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2029     raise ex from inner_exc
#    2031 ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2032 raise ex from exc
#
# DatabaseError: Execution failed on sql 'select * from user': no such table: user

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 from tabula import convert_into
#       2 #df = read_pdf('deliberation.pdf',  pages='all')
#       3 convert_into("deliberation.pdf", "output.csv", output_format="csv", pages='all')
#
# ImportError: cannot import name 'convert_into' from 'tabula' (/home/judi/anaconda3/lib/python3.9/site-packages/tabula/__init__.py)

# %%
# Out:
# Collecting tabula-py
#   Downloading tabula_py-2.4.0-py3-none-any.whl (12.0 MB)
#      |████████████████████████████████| 12.0 MB 70 kB/s  eta 0:00:01
# Requirement already satisfied: numpy in /home/judi/anaconda3/lib/python3.9/site-packages (from tabula-py) (1.21.5)
# Collecting distro
#   Downloading distro-1.7.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: pandas>=0.25.3 in /home/judi/anaconda3/lib/python3.9/site-packages (from tabula-py) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/judi/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/judi/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.3->tabula-py) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/judi/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.25.3->tabula-py) (1.16.0)
# Installing collected packages: distro, tabula-py
# Successfully installed distro-1.7.0 tabula-py-2.4.0
